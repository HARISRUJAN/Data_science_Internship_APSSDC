# %% [markdown]
# wether data visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("weather.csv")
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
df.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
df["temparature"].fillna(df["temparature"].mean(),inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'temparature'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-67f47734438c> in <module>
# ...

# %%
df["winspeed"].fillna(df["winspeed"].mean(),inplace=True)
df

# %%
df["event"].mode()

# %%
df["event"].fillna("fullair",inplace=True)
df

# %%
df.info()

# %%
df.drop("s.no",axis=1,inplace=True)
df

# %%
df.drop_duplicates(["day"],keep="first",inplace=True)
df

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['day']=le.fit_transform(df['day'])
df['event']=le.fit_transform(df['event'])

# %%
df

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
s=StandardScaler()
m=MinMaxScaler()
r=RobustScaler()
n=Normalizer()

# %%
s1=s.fit_transform(df) 
m1=m.fit_transform(df)
r1=r.fit_transform(df)
n1=n.fit_transform(df)

# %%
plt.plot(df,marker="o")
plt.title("before scaling")
plt.legend(["Day","Temparature","windspeed","sales"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1522         try:
# -> 1523             ret = self.converter.convert(x, self.units, self)
#    1524         except Exception as e:
#
# ~\anaconda3\lib\site-packages\matplotlib\category.py in convert(value, unit, axis)
#      48         if unit is None:
# ---> 49             raise ValueError(
#      50                 'Missing category information for StrCategoryConverter; '
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# <ipython-input-12-a25d552582a2> in <module>
# ----> 1 plt.plot(df,marker="o")
# ...

# %%
plt.plot(s1,marker="o")
plt.title("After Applying Standard  scaling")
plt.legend(["Day","Temparature","windspeed","sales"])
plt.show()

# %%
plt.plot(m1,marker="o")
plt.title("After Applying minmax  scaling")
plt.legend(["Day","Temparature","windspeed","sales"])
plt.show()

# %%
plt.plot(r1,marker="o")
plt.title("After Applying Robust  scaling")
plt.legend(["Day","Temparature","windspeed","sales"])
plt.show()

# %%
plt.plot(n1,marker="o")
plt.title("After Applying  Normalizer  scaling")
plt.legend(["Day","Temparature","windspeed","sales"])
plt.show()

# %%
plt.plot(df["temparature"],df["event"],marker="*")
plt.title("Temparature vs Event")
plt.xlabel("Temparature")
plt.ylabel("Event")
plt.show()

# %%
plt.subplots(1,3)
plt.subplot(1,3,1)
plt.plot(df["day"],df["event"],marker="*")
plt.title("Day vs Event")
plt.xlabel("Day")
plt.ylabel("Event")
plt.subplot(1,3,2)
plt.plot(df["temparature"],df["event"],marker="*")
plt.title("Temparature vs Event")
plt.xlabel("Temparature")
plt.ylabel("Event")
plt.subplot(1,3,3)
plt.plot(df["winspeed"],df["event"],marker="*")
plt.title("Windspeed vs Event")
plt.xlabel("Windspeed")
plt.ylabel("Event")
plt.subplots_adjust(left=0,bottom=0.1, right=2, top=0.9,wspace=0.4,hspace=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'day'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-2de367cab5f6> in <module>
#       1 plt.subplots(1,3)
# ...
